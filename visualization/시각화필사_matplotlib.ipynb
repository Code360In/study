# %% [markdown]
# # 시각화 공부
# # Matplotlib

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 코렙 한글폰트 적용
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# !apt -qq -y install fonts-nanum > /dev/null
 
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
 
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()
 
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'
 
# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 기본값 설정

# %%
plt.rcParams['figure.figsize'] = (10,10)
plt.rcParams['figure.dpi'] = 80 #선택적 해상도 설정
plt.rcParams['lines.linewidth'] = 3 # 굵기 정하기
plt.rcParams["lines.color"] = "r" # 색상 정하기
plt.rcParams['axes.grid'] = True

plt.rcParams['font.family'] = 'NanumBarunGothic'
plt.rcParams['font.size'] = 14

# %% [markdown]
# ## 스타일

# %% [markdown]
# - 스타일시트
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(10,6))

data = [5, 12, 23, 45, 32]
ax.plot(data)
plt.savefig('plt1.png', dpi=80)
plt.show()

# %% [markdown]
# ## 폰트 설정

# %%
import matplotlib as mpl

font_setting0 = mpl.font_manager.FontProperties()
font_setting0.set_family('Dejavu Sans') # 'serif', 'sans-serif', 'cursive', 'fantasy', 'monospace'
font_setting0.set_size(20)
font_setting0.set_style('normal') # 'normal', 'oblique', 'italic'
font_setting0.set_weight('bold')

fig, ax = plt.subplots(figsize=(10,6))

data = [5, 12, 23, 45, 32]
ax.plot(data)
ax.set_title("title", FontProperties= font_setting0)
plt.show()

# %%
fontdict = {
    'family': 'cursive',
    'size': 25,
    'backgroundcolor': 'yellow',
    'color': 'blue',
    'weight': 'normal',
    'verticalalignment': 'baseline',
    'horizontalalignment': 'left'
}
fig, ax = plt.subplots(figsize=(10,6))

data = [5, 12, 23, 45, 32]
ax.plot(data)
ax.set_title("title", fontdict = fontdict )

plt.suptitle('subtitle', fontdict = fontdict)
plt.subplots_adjust(top=0.7)
plt.show()
# Out:
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## 색상

# %%
import pandas as pd
from sklearn.datasets import load_boston

boston = load_boston()
print(boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
# 위의 각 데이터들이 target데이터와 어떤 관계가 있는지 확인해 봅니다.
dfX = pd.DataFrame(boston.data, columns=boston.feature_names)
dfy = pd.DataFrame(boston.target, columns=["MEDV"])
dfb = pd.concat([dfX, dfy], axis=1)

# 확인결과 결측치 존재x
dfb.describe()
# Out:
#              CRIM          ZN       INDUS  ...           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677083   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %%
fig, ax = plt.subplots(figsize=(10,6), ncols=5, nrows=3)   # 그래프를 5 x 3으로 배열합니다.

axes = ax.ravel()              # 5 x 3 으로 생성된 subplot을 1 x 15로 변환해 줍니다.
feats = boston.feature_names   # feature 이름을 가져옵니다.
for i, col in enumerate(dfb.columns):            # column의 순서와 이름을 동시에 가지고 옵니다.
    axes[i].scatter(dfb[col], dfb['MEDV'], s=3)  # scatter plot을 그립니다. / s는 스칼라 배열 
    axes[i].set_xlabel(col)                      # x label에 feature 이름을 넣어줍니다.

plt.tight_layout() # 서브플롯의 크기 또는 간격 개선
plt.plot()
# 각 인자들이 어떤지 한눈에 안들어와 한글 입력
# Out:
# []
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
labels_kr = [  
    "범죄율",
    "25kft2 초과 비율",
    "비상업 면적비율",
    "찰스강 근교 여부",
    "일산화질소 농도",
    "평균 방 수",
    "< 1940년 주택 비율",
    "직업센터까지 거리",
    "고속도로까지 거리",
    "재산세율",
    "학생 교사 비율",
    "흑인 비율",
    "하위 계층 비율",
    "주택 가격 (중앙값)",
]

cols = dfb.columns  
labelb = dict(zip(cols, labels_kr)) # feature 이름과 한글 이름을 쌍으로 하는 dictionary를 만들어 줍니다.
print(labelb)  # 생성된 dictionary를 확인합니다.
# Out:
# {'CRIM': '범죄율', 'ZN': '25kft2 초과 비율', 'INDUS': '비상업 면적비율', 'CHAS': '찰스강 근교 여부', 'NOX': '일산화질소 농도', 'RM': '평균 방 수', 'AGE': '< 1940년 주택 비율', 'DIS': '직업센터까지 거리', 'RAD': '고속도로까지 거리', 'TAX': '재산세율', 'PTRATIO': '학생 교사 비율', 'B': '흑인 비율', 'LSTAT': '하위 계층 비율', 'MEDV': '주택 가격 (중앙값)'}

# %%
fig, ax = plt.subplots(figsize=(10,6), ncols=5, nrows=3)   
axes = ax.ravel()      
feats = boston.feature_names  
for i, col in enumerate(dfb.columns):      
    axes[i].scatter(dfb[col], dfb['MEDV'], s=3)  
    axes[i].set_xlabel(labelb[col]) #수정부분

plt.tight_layout()
plt.plot()
# Out:
# []
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# DIS(직업센터까지 거리)와 MED(주택 가격: 중앙값)
fig, ax = plt.subplots(figsize=(6,6))

ax.scatter(dfb['DIS'], dfb['MEDV'], s=5)
ax.set_xlabel(labelb['DIS'])
ax.set_ylabel(labelb['MEDV'])

plt.tight_layout()

# %% [markdown]
# - 분석결과 두 변수간에는 양의 상관관계가 보이는데 1940년 이전에는 그런 관계가 안보여!
# - c: color. 색상이나 변수명을 입력 가능

# %%
fig, ax = plt.subplots(figsize=(4,4))

ax.scatter(dfb['DIS'], dfb['MEDV'], s=5, c=dfb['AGE'], cmap='jet', alpha=0.5)
ax.set_xlabel(labelb['DIS'])
ax.set_ylabel(labelb['MEDV'])

plt.tight_layout()

# %% [markdown]
# 실행 결과 AGE(1940년 이전 주택 비율) 데이터가 입혀짐 -> DIS가 짧을 수록 노후한 주택이 많다

# %% [markdown]
# ## Colorbar

# %%
fig, ax = plt.subplots(figsize=(4,4))

im = ax.scatter(dfb['DIS'], dfb['MEDV'], s=5, c=dfb['AGE'], cmap='jet', alpha=0.5)
ax.set_xlabel(labelb['DIS'])
ax.set_ylabel(labelb['MEDV'])

cbar = plt.colorbar(im) # colorbar 지정
cbar.set_label(labelb['AGE']) # colorbar label 지정
plt.tight_layout()

# %% [markdown]
# ## Axes

# %% [markdown]
# ### matplotlib.pyplot

# %%
plt.plot([1, 4, 9, 16])
plt.ylabel('some numbers')
plt.show()

# %%
plt.style.use('default')

names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %% [markdown]
# ### figure and axes

# %%
fig, ax = plt.subplots()

# %%
import seaborn as sns

plt.style.use('seaborn-whitegrid') # background color, grid color
sns.set_context('talk') # fontsize, linewidth 등은 seaborn의 seaborn.set_context()를 사용

fig, ax = plt.subplots(figsize=(7,3))

# %% [markdown]
# ### Data Preparation

# %%
data = {'Barton LLC': 109438.50,
        'Frami, Hills and Schmidt': 103569.59,
        'Fritsch, Russel and Anderson': 112214.71,
        'Jerde-Hilpert': 112591.43,
        'Keeling LLC': 100934.30,
        'Koepp Ltd': 103660.54,
        'Kulas Inc': 137351.96,
        'Trantow-Barrows': 123381.38,
        'White-Trantow': 135841.99,
        'Will LLC': 104437.60}
group_data = list(data.values())
group_names = list(data.keys())

# %%
fig, ax = plt.subplots(figsize=(7,4))
ax.barh(group_names, group_data)
# Out:
# <BarContainer object of 10 artists>

# %%
import pandas as pd

# DataFrame.from_dict() 이용해서 datafram으로 변경
df = pd.DataFrame.from_dict(data, orient='index', columns=['revenue'])
df
# Out:
#                                 revenue
# Barton LLC                    109438.50
# Frami, Hills and Schmidt      103569.59
# Fritsch, Russel and Anderson  112214.71
# Jerde-Hilpert                 112591.43
# Keeling LLC                   100934.30
# Koepp Ltd                     103660.54
# Kulas Inc                     137351.96
# Trantow-Barrows               123381.38
# White-Trantow                 135841.99
# Will LLC                      104437.60

# %%
df.plot(kind='barh')

# %%
sns.set_palette('bright') #  seaborn.set_palette를 이용하여 색상 변경

fig, ax = plt.subplots(figsize=(7,4))
ax.barh(group_names, group_data)
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots(figsize=(7,4))
sns.barplot(group_data, group_names)

# %%
fig, ax = plt.subplots(figsize=(7,4))
sns.barplot(group_data, group_names)

ax.set_xlabel('Total Revenue') # x축
ax.set_ylabel('Company') # y축
ax.set_title('Company Revenue') # 제목
# Out:
# Text(0.5, 1.0, 'Company Revenue')

# %%
font_label = {
    'color': 'gray',
    'weight': 'bold'
}

font_title = {
    'family': 'serif',
    'size': 20,
#     'backgroundcolor': 'yellow',
    'color': 'brown',
    'weight': 'bold',
    'verticalalignment': 'baseline', # 텍스트의 baseline에 따라 달라짐(center,top,bottom 텍스트 정렬)
    'horizontalalignment': 'center'  # 텍스트의 수평방향(left, right 좌표 중앙 좌 우)
}

fig, ax = plt.subplots(figsize=(7,4))
sns.barplot(group_data, group_names)

# label 지정
ax.set_xlabel('Total Revenue ($)', fontdict=font_label, labelpad=20) # label 거리간격지정
ax.set_ylabel('Company', fontdict=font_label, labelpad=20)
ax.set_title('Company Revenue', fontdict=font_title, pad=20) # 제목에서 거리간격지정

# 간격 지정
ax.set_xlim(75000, 150000) # x축 범위 지정 

# 45도 회전
xlabels = ax.get_xticks()
print(f'xlabels type={type(xlabels)}, \nxlabels={xlabels}')
ax.set_xticklabels(xlabels.astype('int'), rotation=45, 
                   horizontalalignment='right')

# x축의 label 데이터 보기 안좋아 변환
ax.set_xticklabels([f'{xlabel/1000:0.0f}K' for xlabel in xlabels])

plt.show()
# Out:
# xlabels type=<class 'numpy.ndarray'>,
# xlabels=[ 60000.  80000. 100000. 120000. 140000. 160000.]

# %%
# 추가 작업
font_label = {
    'color': 'gray',
    'weight': 'bold'
}

font_title = {
    'family': 'serif',
    'size': 20,
#     'backgroundcolor': 'yellow',
    'color': 'brown',
    'weight': 'bold',
    'verticalalignment': 'baseline', # 텍스트의 baseline에 따라 달라짐(center,top,bottom 텍스트 정렬)
    'horizontalalignment': 'center'  # 텍스트의 수평방향(left, right 좌표 중앙 좌 우)
}

fig, ax = plt.subplots(figsize=(7,4))
sns.barplot(group_data, group_names)

# label 지정
ax.set_xlabel('Total Revenue ($)', fontdict=font_label, labelpad=20) # label 거리간격지정
ax.set_ylabel('Company', fontdict=font_label, labelpad=20)
ax.set_title('Company Revenue', fontdict=font_title, pad=20) # 제목에서 거리간격지정

# 간격 지정
ax.set_xlim(75000, 150000) # x축 범위 지정 

# 45도 회전
xlabels = ax.get_xticks()
print(f'xlabels type={type(xlabels)}, \nxlabels={xlabels}')
ax.set_xticklabels(xlabels.astype('int'), rotation=45, 
                   horizontalalignment='right')

# x축의 label 데이터 보기 안좋아 변환
ax.set_xticklabels([f'{xlabel/1000:0.0f}K' for xlabel in xlabels])

# 추가작업
import numpy as np

font_text = {
    'size': 10,
    'color': 'white',
    'weight': 'bold',
    'horizontalalignment': 'left',
    'verticalalignment': 'center'
}

# ax.axvline
group_mean = np.mean(group_data)
ax.axvline(group_mean, ls='-', lw=3, color='#8C87') # 수직선(평균값)

# ax.annotate - 수직선 평균이라는 것을 알려주기 위해 화살표와 텍스트 추가
arrowprops = {
    'arrowstyle': '->'
}
ax.annotate("average", (group_mean, 2.5), xytext=(125000, 2.5),
          color='green', fontfamily='serif', fontstyle='italic', fontsize=15,
          arrowprops=arrowprops)

# ax.text() - bar 위에 원하는거 글자로 표시
for group in [3, 5, 8]:
    ax.text(80000, group, "New Company", fontdict=font_text)

plt.show()
# Out:
# xlabels type=<class 'numpy.ndarray'>,
# xlabels=[ 60000.  80000. 100000. 120000. 140000. 160000.]
