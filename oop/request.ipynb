# %% [markdown]
# <a href="https://colab.research.google.com/github/mjs1995/study/blob/main/oop/request.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # requests
# https://me2nuk.com/Python-requests-module-example/

# %% [markdown]
# - HTTP 요청 메서드(HTTP request method)
#     - http 메서드는 클라이언트가 서버에게 요청하는 목적 및 그 종류를 알리는 수단
#     - 요청 메서드냐에 따라 요청/응답하는 방식 또한 다르며 다양한 메서드가 존재
#     - 대표적으로 쓰이는 메서드는 GET, POST 방식
# - References
#     - HTTP method Documentation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # pytz
# from pytz import timezone

# %% [markdown]
# 세계 시간대 정의를 위한 Python 라이브러리

# %% [markdown]
# ![image.png](data:image/png;base64,...)
