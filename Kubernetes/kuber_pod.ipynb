# %% [markdown]
# # 배포를 통해 확인하는 파드(Pod)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 외부에서 접속하게 하는 방법

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 디플로이먼트를 통해서 배포

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 노드포트로 노출 및 로드밸런서

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 노드포트의 문제 : 노드의 IP를 그대로 알려주긴 힘들기 때문! 비밀번호 같은 느낌이라 로드밸런서 타입으로 알려주기
# - 고유의 IP를 만들어서 알려주기 때문에 부담감 적어
# - 가야될 경로를 최적화해서 알려줄 수 있어

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# # 코드로 형식 지정됨
# ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 배포한것들 삭제하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
