# %% [markdown]
# # 쿠버네티스

# %% [markdown]
# - 쿠버네티스 배포 종류

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## kubeadm

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 코드로 설치하는 쿠버네티스 랩 환경
# - 웹에서 제공
#     * 플레이 쿠버네티스(시간제약) : https://labs.play-with-k8s.com/
#     * 쿠버네티스 플레이그라운드(노드제한, 자유로운 사용 불가) : https://www.katacoda.com/courses/kubernetes/playground

# %% [markdown]
# - cmd : window + r > vagrant > vagrant --version : 버전확인하기
# - 코드 내려받기 : https://github.com/sysnet4admin/_Lecture_k8s_starter.kit > c:\HashiCorp 압축풀기
# - 명령창 cd c:\HashiCorp > cd _Lecture_k8s_starter.kit-main > cd ch1 > cd 1.2 > cd k8s-min-5GiB > vagrant up
# - root / vagrant -> kubectl get nodes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 터미널로 연결하는 방법
# - putty 설치 : https://www.chiark.greenend.org.uk/~sgtatham/putty/latest.html
# - supperputty 설치 : https://github.com/jimradford/superputty/releases

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
